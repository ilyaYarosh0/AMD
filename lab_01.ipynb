# %%
import math

# %%
i = 9801
print(int(i/9))
# Out:
# 1089

# %%
x = 2176782336
answer = int(math.log(x,6))
print(answer)
# Out:
# 12

# %%
answer1_2 = math.log(10)*5
print(f"{answer1_2:.5f}")
# Out:
# 11.51293

# %%
answer1_3 = math.sin(math.pi)
print(answer1_3)
answer1_4 = math.sin((math.pi)/2)
print(answer1_4)
answer1_5 = round(math.sin((math.pi)/6), 2)
print(answer1_5)
# Out:
# 1.2246467991473532e-16
# 1.0
# 0.5
