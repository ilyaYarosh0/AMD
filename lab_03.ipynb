# %%
import numpy as np

# %%
vec = np.array([3, "Мой","вектор"])
print(vec)
# Out:
# ['3' 'Мой' 'вектор']

# %%
res = 10 - True
print(res)
# Out:
# 9

# %%
vec2 = np.array([10, True])
print(vec2)

por=np.append(vec2, "r")
print(por)
# Out:
# [10  1]
# ['10' '1' 'r']

# %%
mix =np.array([10, True, "r"])
print(mix)
# Out:
# ['10' 'True' 'r']
